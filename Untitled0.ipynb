# %% [markdown]
# <a href="https://colab.research.google.com/github/aranzatorres546-hash/M-TODOS-NUM-RICOS-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def f(x):
  return (x-2)**2

# %%
f(2)
# Out:
# 0
